# %% [markdown]
# # T2 GovTrust-FL diagnostic preflight
# This notebook performs environment/preflight checks only. It does **not** start scientific training automatically.

# %%
# !python -m pip install -q -r requirements-t2.txt

# %%
# !python scripts/t2/preflight.py

# %%
# !python -m src.t2.cli plan
